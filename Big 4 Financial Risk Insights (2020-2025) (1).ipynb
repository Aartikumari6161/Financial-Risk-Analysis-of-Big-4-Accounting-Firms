# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\AARTI KUMARI\Desktop\Dataset for prectice\2020 to 2025.csv")

# %%
dataset.head()
# Out:
#    Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# 0  2020       PwC                     2829               51
# 1  2022  Deloitte                     3589              185
# 2  2020       PwC                     2438              212
# 3  2021       PwC                     2646              397
# 4  2020       PwC                     2680              216
#
#    Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# 0                    123                    39        Healthcare
# 1                     30                    60        Healthcare
# 2                    124                    97        Healthcare
# 3                     55                    97        Healthcare
# 4                     99                    46        Healthcare
#
#    Total_Revenue_Impact AI_Used_for_Auditing  Employee_Workload  \
# 0                114.24                   No                 57
# 1                156.98                  Yes                 58
# ...

# %%
dataset.shape
# Out:
# (100, 12)

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dataset.dtypes
# Out:
# Year                           int64
# Firm_Name                     object
# Total_Audit_Engagements        int64
# High_Risk_Cases                int64
# Compliance_Violations          int64
# Fraud_Cases_Detected           int64
# Industry_Affected             object
# Total_Revenue_Impact         float64
# AI_Used_for_Auditing          object
# Employee_Workload              int64
# Audit_Effectiveness_Score    float64
# Client_Satisfaction_Score    float64
# dtype: object

# %%
dataset.describe()
# Out:
#               Year  Total_Audit_Engagements  High_Risk_Cases  \
# count   100.000000               100.000000       100.000000
# mean   2022.320000              2784.520000       277.730000
# std       1.780251              1281.863073       135.735174
# min    2020.000000               603.000000        51.000000
# 25%    2021.000000              1768.250000       162.500000
# 50%    2022.000000              2650.000000       293.000000
# 75%    2024.000000              4008.750000       395.500000
# max    2025.000000              4946.000000       500.000000
#
#        Compliance_Violations  Fraud_Cases_Detected  Total_Revenue_Impact  \
# count             100.000000            100.000000            100.000000
# mean              105.480000             52.700000            272.539000
# std                55.370101             28.311221            139.151401
# min                10.000000              5.000000             33.460000
# ...

# %%
dataset.describe(include='all')
# Out:
#                Year Firm_Name  Total_Audit_Engagements  High_Risk_Cases  \
# count    100.000000       100               100.000000       100.000000
# unique          NaN         4                      NaN              NaN
# top             NaN  Deloitte                      NaN              NaN
# freq            NaN        30                      NaN              NaN
# mean    2022.320000       NaN              2784.520000       277.730000
# std        1.780251       NaN              1281.863073       135.735174
# min     2020.000000       NaN               603.000000        51.000000
# 25%     2021.000000       NaN              1768.250000       162.500000
# 50%     2022.000000       NaN              2650.000000       293.000000
# 75%     2024.000000       NaN              4008.750000       395.500000
# max     2025.000000       NaN              4946.000000       500.000000
#
#         Compliance_Violations  Fraud_Cases_Detected Industry_Affected  \
# ...

# %%
num_data = dataset.select_dtypes(include=[np.number])

# %%
num_data.head()
# Out:
#    Year  Total_Audit_Engagements  High_Risk_Cases  Compliance_Violations  \
# 0  2020                     2829               51                    123
# 1  2022                     3589              185                     30
# 2  2020                     2438              212                    124
# 3  2021                     2646              397                     55
# 4  2020                     2680              216                     99
#
#    Fraud_Cases_Detected  Total_Revenue_Impact  Employee_Workload  \
# 0                    39                114.24                 57
# 1                    60                156.98                 58
# 2                    97                131.83                 76
# 3                    97                229.11                 60
# 4                    46                 48.00                 51
#
#    Audit_Effectiveness_Score  Client_Satisfaction_Score
# 0                        5.8                        8.4
# ...

# %%
plt.figure(figsize=(9,6))
sns.heatmap(num_data.corr() , annot = True , cmap = 'coolwarm')
plt.title('Corrilation Heatmap')
plt.show()

# %%
for col in dataset:
    sns.histplot(x=col,data=dataset,kde=True)
    plt.show()

# %%
dataset.columns
# Out:
# Index(['Year', 'Firm_Name', 'Total_Audit_Engagements', 'High_Risk_Cases',
#        'Compliance_Violations', 'Fraud_Cases_Detected', 'Industry_Affected',
#        'Total_Revenue_Impact', 'AI_Used_for_Auditing', 'Employee_Workload',
#        'Audit_Effectiveness_Score', 'Client_Satisfaction_Score'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
featurs = ['Total_Audit_Engagements', 'High_Risk_Cases', 'Compliance_Violations',
            'Fraud_Cases_Detected', 'Total_Revenue_Impact', 'Employee_Workload', 'Client_Satisfaction_Score']

target = 'Audit_Effectiveness_Score'

# %%
x = dataset[featurs].copy()
y = dataset[target].copy()

# %%
x_train , x_test ,y_train , y_test = train_test_split(x , y , test_size=0.30 , random_state=42)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([7.57653657, 8.48850449, 6.50719016, 8.16031099, 7.23542376,
#        7.67859612, 7.15069381, 8.27840523, 7.50707375, 7.52673582,
#        7.95901002, 7.99265531, 6.68422013, 7.43099437, 6.65597559,
#        7.16996387, 6.75284259, 6.60041373, 7.44244709, 7.36343243,
#        7.33170986, 6.94431278, 6.90084916, 7.30302444, 7.71352792,
#        7.15984442, 7.54172906, 7.74867832, 7.78368544, 7.94253053])

# %%
r2 = r2_score(y_test, y_pred)

# %%
print('R² score for predicting Audit_Effectiveness_Score:', r2)
# Out:
# R² score for predicting Audit_Effectiveness_Score: -0.27121987757118915

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Audit Effectiveness Score')
plt.ylabel('Predicted Audit Effectiveness Score')
plt.title('Actual vs Predicted Audit Effectiveness Score')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', lw=2)
